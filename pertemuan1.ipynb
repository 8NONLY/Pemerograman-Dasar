# %% [markdown]
# <a href="https://colab.research.google.com/github/8NONLY/Pemerograman-Dasar/blob/main/pertemuan1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Biodata saya

nama= "Muhamad Hadi Wibowo Mulyadi"
umur= "19"
jurusan= "RPE"
semester= "3"
matakuliah='Pemrograman Dasar'
status_lulus= False


print(nama)
print(umur)
print(jurusan)
print(semester)
print(matakuliah)
print(status_lulus)
# Out:
# Muhamad Hadi Wibowo Mulyadi
# 19
# RPE
# 3
# Pemrograman Dasar
# False

# %%
nama= "Muhamad Hadi Wibowo Mulyadi"
nim= 4232501060
jurusan= "elektro"
prodi= 'Teknologi Rekayasa Pembangkit Energi'
semester= "3(tiga)"
umur= 19
matakuliah= "pemrograman dasar"
kota_tinggal= "batam"
tempat_lahir= "bandung"
status_lulus= False


print(nama)
print(nim)
print(jurusan)
print(prodi)
print(semester)
print(umur)
print(matakuliah)
print(kota_tinggal)
print(tempat_lahir)
print(status_lulus)
# Out:
# Muhamad Hadi Wibowo Mulyadi
# 4232501060
# elektro
# Teknologi Rekayasa Pembangkit Energi
# 3(tiga)
# 19
# pemrograman dasar
# batam
# bandung
# False
